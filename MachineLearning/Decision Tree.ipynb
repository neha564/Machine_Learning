# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split

# %%
#Load the data sets- train and test 
df=pd.read_csv("/home/rgukt-basar/MachineLearning/train_titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Look at top values of train data 
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print the column names of train data
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data
df.shape
# Out:
# (891, 12)

# %%
#Print the number of missing values in each column of train and test data
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked
import seaborn as sns
col=['Survived','Pclass','Sex','Embarked']
#import seaborn as sns']
for i in col:
    sns.countplot(data=df,x=i)
    plt.show()

# %%
#Histogram of Age, Parch, Fare
col=['Age','Parch','Fare']
#import seaborn as sns']
for i in col:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Plot histogram of age for survived and did not survived class
#import seaborn as sns
#import numpy as np
plt.hist(data=df,x='Survived')
plt.xticks([0,1],['Not Survived','Survived'])
# Out:
# ([<matplotlib.axis.XTick at 0x73de3f4c41c0>,
#   <matplotlib.axis.XTick at 0x73de3f4c4190>],
#  [Text(0, 0, 'Not Survived'), Text(1, 0, 'Survived')])

# %%
#Count class and geder wise survival rate - plot with appropriate chart
#Age wise Distribution of Male and Female passengers
total_counts = df.groupby(['Pclass', 'Sex'])['Survived'].count()
print(total_counts)
sns.catplot(data=df,x='Pclass',hue='Sex',col='Survived',kind='count')
plt.show()

#Age wise Distribution of Male and Female passengers
sns.histplot(data=df,x='Age',hue='Sex',kde=True)
plt.show()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: Survived, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3534/890105796.py in <module>
#       7
#       8 #Age wise Distribution of Male and Female passengers
# ----> 9 sns.histplot(data=df,x='Age',hue='Sex',kde=True)
#      10 plt.show()
#
# ~/.local/lib/python3.10/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# ~/.local/lib/python3.10/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     649
#     650                 line_kws["color"] = to_rgba(sub_color, 1)
# --> 651                 line, = ax.plot(
#     652                     *line_args, **line_kws,
#     653                 )
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     485
#     486         if len(xy) == 2:
# --> 487             x = _check_1d(xy[0])
#     488             y = _check_1d(xy[1])
#     489         else:
#
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py in _check_1d(x)
#    1325                     message='Support for multi-dimensional indexing')
#    1326
# -> 1327                 ndim = x[:, None].ndim
#    1328                 # we have definitely hit a pandas index or series object
#    1329                 # cast to a numpy array.
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
# -> 5419             disallow_ndim_indexing(result)
#    5420
#    5421         # NB: Using _constructor._simple_new would break if MultiIndex
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexers/utils.py in disallow_ndim_indexing(result)
#     339     """
#     340     if np.ndim(result) > 1:
# --> 341         raise ValueError(
#     342             "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343             "supported. Convert to a numpy array before indexing instead."
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
#Histogram of Age of the given data set(sample)
sns.histplot(data=df,x=df['Age'])
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the msiing values in Embarked column by 'S'
df['Embarked']=df['Embarked'].fillna(df['Embarked']=='S')
df
#print(df.isnull().sum())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Impute the missing values in Fare column with median value
df['Fare']=df['Fare'].fillna(df['Fare'].median())

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data
df['Age']=df['Age'].fillna(df['Age'].median())

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1
df['FamilySize'] =df['Parch']+df['SibSp']+1 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  FamilySize  IsAlone
# 0        0         A/5 21171   7.2500   NaN        S           2    False
# 1        0          PC 17599  71.2833   C85        C           2    False
# 2        0  STON/O2. 3101282   7.9250   NaN        S           1     True
# 3        0            113803  53.1000  C123        S           2    False
# 4        0            373450   8.0500   NaN        S           1     True
# ..     ...               ...      ...   ...      ...         ...      ...
# 886      0            211536  13.0000   NaN        S           1     True
# 887      0            112053  30.0000   B42        S           1     True
# 888      2        W./C. 6607  23.4500   NaN        S           4    False
# 889      0            111369  30.0000  C148        C           1     True
# 890      0            370376   7.7500   NaN        Q           1     True
#
# [891 rows x 14 columns]

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
import numpy as np
df['IsAlone'] = np.where(df['FamilySize'] == 1, True, False)

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin
s=df.drop(columns=['PassengerId','Name','Ticket','Cabin'])
s
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  28.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
#      FamilySize  IsAlone
# 0             2    False
# 1             2    False
# 2             1     True
# 3             2    False
# 4             1     True
# ..          ...      ...
# 886           1     True
# 887           1     True
# 888           4    False
# 889           1     True
# 890           1     True
#
# [891 rows x 10 columns]

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y
x=df.values[:, 1:10]
y=df.values[:, 0]

# %%
# Label encoding of categorical features
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
s['Sex']=label.fit_transform(s['Sex'])
s['IsAlone']=label.fit_transform(s['IsAlone'])
#s['Embarked_Q']=label.fit_transform(s['Embarked_Q'])
#s['Embarked_S']=label.fit_transform(s['Embarked_S'])
#s=s.drop(columns=['Embarked_C'])
t=pd.get_dummies(s,columns=['Embarked'],drop_first=True).replace({True:1,False:0})
t
# Out:
# /tmp/ipykernel_3534/1425311727.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   t=pd.get_dummies(s,columns=['Embarked'],drop_first=True).replace({True:1,False:0})
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  FamilySize  IsAlone  \
# 0           0       3    1  22.0      1      0   7.2500           2        0
# 1           1       1    0  38.0      1      0  71.2833           2        0
# 2           1       3    0  26.0      0      0   7.9250           1        1
# 3           1       1    0  35.0      1      0  53.1000           2        0
# 4           0       3    1  35.0      0      0   8.0500           1        1
# ..        ...     ...  ...   ...    ...    ...      ...         ...      ...
# 886         0       2    1  27.0      0      0  13.0000           1        1
# 887         1       1    0  19.0      0      0  30.0000           1        1
# 888         0       3    0  28.0      1      2  23.4500           4        0
# 889         1       1    1  26.0      0      0  30.0000           1        1
# 890         0       3    1  32.0      0      0   7.7500           1        1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 12 columns]

# %%
# concat df_categorical with original df
#t.columns
t
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  FamilySize  IsAlone  \
# 0           0       3    1  22.0      1      0   7.2500           2        0
# 1           1       1    0  38.0      1      0  71.2833           2        0
# 2           1       3    0  26.0      0      0   7.9250           1        1
# 3           1       1    0  35.0      1      0  53.1000           2        0
# 4           0       3    1  35.0      0      0   8.0500           1        1
# ..        ...     ...  ...   ...    ...    ...      ...         ...      ...
# 886         0       2    1  27.0      0      0  13.0000           1        1
# 887         1       1    0  19.0      0      0  30.0000           1        1
# 888         0       3    0  28.0      1      2  23.4500           4        0
# 889         1       1    1  26.0      0      0  30.0000           1        1
# 890         0       3    1  32.0      0      0   7.7500           1        1
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 11 columns]

# %%
#Do a pairplot of all features
sns.pairplot(t)
plt.show()

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  FamilySize  IsAlone  \
# 0         3    1  22.0      1      0   7.2500           2        0
# 1         1    0  38.0      1      0  71.2833           2        0
# 2         3    0  26.0      0      0   7.9250           1        1
# 3         1    0  35.0      1      0  53.1000           2        0
# 4         3    1  35.0      0      0   8.0500           1        1
# ..      ...  ...   ...    ...    ...      ...         ...      ...
# 886       2    1  27.0      0      0  13.0000           1        1
# 887       1    0  19.0      0      0  30.0000           1        1
# 888       3    0  28.0      1      2  23.4500           4        0
# 889       1    1  26.0      0      0  30.0000           1        1
# 890       3    1  32.0      0      0   7.7500           1        1
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 10 columns]

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
x=t[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','FamilySize', 'IsAlone','Embarked_Q', 'Embarked_S']]
y=t['Survived']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier,plot_tree
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Print the tree

# Importing required packages for visualization
import seaborn as sns
plot_tree(model, feature_names=x.columns, class_names=["0", "1"], filled=True)
plt.show()

# %%
# plotting tree with max_depth=3
plot_tree(model, feature_names=x.columns, class_names=["0", "1"], filled=True,max_depth=3)
plt.show()

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
y_pred = model.predict(x_test)  # Predictions on validation set
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Precision
precision = precision_score(y_test, y_pred)
print(f"Precision: {precision:.4f}")

# Recall
recall = recall_score(y_test, y_pred)
print(f"Recall: {recall:.4f}")

# F1 Score
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1:.4f}")
# Out:
# Confusion Matrix:
#  [[95 22]
#  [19 43]]
# Accuracy: 0.7709
# Precision: 0.6615
# Recall: 0.6935
# F1 Score: 0.6772

# %%
# Printing confusion matrix and accuracy
